# %% [markdown]
# 有监督 = 有特征 + 有标签
# 标签连续 -> 回归问题
# 标签不连续 -> 分类问题

# %% [markdown]
# 无监督= 有特征,无标签
# 聚类  依据：样本间相似性

# %% [markdown]
# 1 获取数据 获取经验数据  图像数据  文本数据
# 2 数据基本处理  数据缺失值处理 异常值处理
# 3 特征工程  特征提取  特征预处理   特征降维  特征组合
# 4 机器学习(模型训练)  线性回归 逻辑回归 决策树 GBDT
# 5 模型评估 回归评测指标 分类评测指标 聚类评测指标
# 6 模型预测

# %% [markdown]
# # KNN：
# 算欧式距离
# k近邻：k个较临近的邻居，后进行投票
